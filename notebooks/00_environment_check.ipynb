# %% [markdown]
# # Environment Check
#
# Run every cell top-to-bottom. Each cell verifies one component of the locked stack required by master reference §22. If a cell fails, install the missing package(s) via `pip install -r requirements.txt` and re-run.

# %%
import torch
print(torch.__version__, torch.cuda.is_available())

# %%
import timm
m = timm.create_model("efficientnet_b0", pretrained=False)
print(sum(p.numel() for p in m.parameters()))

# %%
from sentence_transformers import SentenceTransformer  # noqa: F401

# %%
import chromadb
client = chromadb.Client()
print("chromadb ok")

# %%
from src.utils.seeding import set_global_seed
set_global_seed(42)
print("seed ok")

# %%
from src.utils.paths import PROJECT_ROOT, DATA_DIR, CORPUS_RAW_DIR
print(PROJECT_ROOT)
print(DATA_DIR)
print(CORPUS_RAW_DIR)
